# %% [markdown]
# #  Pre-trained Deep Learning Models — Transfer Learning
# ### Skin Cancer Detection ML Project  |  Colab-Style Notebook
# ---
# > **Models:** VGG19, ResNet152V2, InceptionV3, ResNet50, DenseNet201
# > **Task:** Binary Classification — Benign (0) vs Malignant (1)
# > **Strategy:** Transfer learning with frozen ImageNet backbones + custom head
#
# ---
# ##  Sections
# 1. Setup and Imports
# 2. Load Metadata and Image Paths
# 3. Train / Validation / Test Split
# 4. Data Augmentation and Generators
# 5. Transfer Learning Architecture
# 6. Training Each Model
# 7. Evaluation and Confusion Matrices
# 8. Training History Plots
# 9. Performance Summary Table

# %% [markdown]
# ---
# ## 1.  Setup and Imports

# %%
import os
import glob
import warnings
warnings.filterwarnings('ignore')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

sns.set_theme(style='whitegrid')
plt.rcParams.update({'figure.figsize': (12, 5), 'font.size': 12})

print(f'TensorFlow version : {tf.__version__}')
print(f'GPU available      : {len(tf.config.list_physical_devices("GPU")) > 0}')
gpus = tf.config.list_physical_devices('GPU')
print(f'GPUs               : {gpus}')
if gpus:
    for gpu in gpus:
        try:
            tf.config.experimental.set_memory_growth(gpu, True)
            print(f'Enabled dynamic memory growth for {gpu.name}')
        except RuntimeError as e:
            print(e)
# Out:
# TensorFlow version : 2.21.0
# GPU available      : True
# GPUs               : [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Enabled dynamic memory growth for /physical_device:GPU:0

# %% [markdown]
# ---
# ## 2.  Load Metadata and Image Paths

# %%
import os
import glob
import pandas as pd

# Detect if running in Google Colab
try:
    import google.colab
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    print('Running in Google Colab!')
    # Mount Google Drive
    from google.colab import drive
    drive.mount('/content/drive')
    
    # Metadata path
    METADATA_PATH = 'HAM10000_metadata.csv'
    if not os.path.exists(METADATA_PATH):
        METADATA_PATH = '/content/HAM10000_metadata.csv'
    
    IMAGES_DIR = '/content/drive/MyDrive'
else:
    # Local path resolution
    wsl_path = os.path.expanduser('~/data/HAM10000_metadata.csv')
    if os.path.exists(wsl_path):
        METADATA_PATH = wsl_path
        IMAGES_DIR    = os.path.expanduser('~/data')
    elif os.path.exists('data/HAM10000_metadata.csv'):
        METADATA_PATH = 'data/HAM10000_metadata.csv'
        IMAGES_DIR    = 'data'
    elif os.path.exists('../data/HAM10000_metadata.csv'):
        METADATA_PATH = '../data/HAM10000_metadata.csv'
        IMAGES_DIR    = '../data'
    else:
        METADATA_PATH = '../data/HAM10000_metadata.csv'
        IMAGES_DIR    = '../data'

print(f'Metadata Path: {METADATA_PATH}')
print(f'Images Directory: {IMAGES_DIR}')

df = pd.read_csv(METADATA_PATH)

image_paths = []
part1_path = os.path.join(IMAGES_DIR, 'HAM10000_images_part_1')
part2_path = os.path.join(IMAGES_DIR, 'HAM10000_images_part_2')

if os.path.exists(part1_path):
    image_paths.extend(glob.glob(os.path.join(part1_path, '*.jpg')))
if os.path.exists(part2_path):
    image_paths.extend(glob.glob(os.path.join(part2_path, '*.jpg')))

if len(image_paths) == 0:
    image_paths.extend(glob.glob(os.path.join(IMAGES_DIR, '*.jpg')))

if len(image_paths) == 0:
    if IN_COLAB and IMAGES_DIR == '/content/drive/MyDrive':
        print('[WARNING] Scanning the entire Google Drive recursively might be very slow!')
    image_paths.extend(glob.glob(os.path.join(IMAGES_DIR, '**', '*.jpg'), recursive=True))

image_path_dict = {os.path.splitext(os.path.basename(p))[0]: p for p in image_paths}
df['path'] = df['image_id'].map(image_path_dict.get)
df = df.dropna(subset=['path']).reset_index(drop=True)

lesion_danger = {'nv': 0, 'mel': 1, 'bkl': 0, 'bcc': 1, 'akiec': 1, 'vasc': 0, 'df': 0}
df['target']    = df['dx'].map(lesion_danger)
df['class_str'] = df['target'].astype(str)   # needed for flow_from_dataframe

print(f'Dataset: {len(df)} images')
print(df['class_str'].value_counts().to_string())
# Out:
# Metadata Path: /home/shan_ahmedshani/data/HAM10000_metadata.csv
# Images Directory: /home/shan_ahmedshani/data
# Dataset: 10015 images
# class_str
# 0    8061
# 1    1954

# %% [markdown]
# ---
# ## 3. [CUT] Train / Validation / Test Split (70 / 15 / 15)

# %%
train_df, test_df = train_test_split(
    df, test_size=0.15, random_state=42, stratify=df['target']
)
train_df, val_df = train_test_split(
    train_df, test_size=0.15, random_state=42, stratify=train_df['target']
)
from sklearn.utils.class_weight import compute_class_weight
import numpy as np
classes_idx = np.unique(train_df['target'].values)
weights = compute_class_weight(class_weight='balanced', classes=classes_idx, y=train_df['target'].values)
class_weights = dict(zip(classes_idx, weights))
print(f'Calculated Class Weights: {class_weights}')

print(f'Train : {len(train_df):5d} images  | Benign: {(train_df["target"]==0).sum()} | Malignant: {(train_df["target"]==1).sum()}')
print(f'Val   : {len(val_df):5d} images  | Benign: {(val_df["target"]==0).sum()}   | Malignant: {(val_df["target"]==1).sum()}')
print(f'Test  : {len(test_df):5d} images  | Benign: {(test_df["target"]==0).sum()}   | Malignant: {(test_df["target"]==1).sum()}')
# Out:
# Calculated Class Weights: {np.int64(0): np.float64(0.6212433453546282), np.int64(1): np.float64(2.561968838526912)}
# Train :  7235 images  | Benign: 5823 | Malignant: 1412
# Val   :  1277 images  | Benign: 1028   | Malignant: 249
# Test  :  1503 images  | Benign: 1210   | Malignant: 293

# %% [markdown]
# ---
# ## 4.  Data Augmentation and Generators

# %%
#  Augmentation for training 
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=True,
    zoom_range=0.1,
    shear_range=0.05
)
val_test_datagen = ImageDataGenerator(rescale=1./255)

BATCH_SIZE = 16

def make_generators(target_size=(224, 224)):
    train_gen = train_datagen.flow_from_dataframe(
        train_df, x_col='path', y_col='class_str',
        target_size=target_size, class_mode='binary',
        batch_size=BATCH_SIZE, shuffle=True
    )
    val_gen = val_test_datagen.flow_from_dataframe(
        val_df, x_col='path', y_col='class_str',
        target_size=target_size, class_mode='binary',
        batch_size=BATCH_SIZE, shuffle=False
    )
    test_gen = val_test_datagen.flow_from_dataframe(
        test_df, x_col='path', y_col='class_str',
        target_size=target_size, class_mode='binary',
        batch_size=BATCH_SIZE, shuffle=False
    )
    return train_gen, val_gen, test_gen

# Default generators for 224x224
train_gen, val_gen, test_gen = make_generators(target_size=(224, 224))
print('[OK] Generators ready')
# Out:
# Found 7235 validated image filenames belonging to 2 classes.
# Found 1277 validated image filenames belonging to 2 classes.
# Found 1503 validated image filenames belonging to 2 classes.
# [OK] Generators ready

# %% [markdown]
# ### 4.2  Data Augmentation Visualization
# Here we load a sample image from the training set and visualize the random augmentations applied by `train_datagen` to verify the effect of rotation, shifts, zoom, flips, and shear.

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt

# Select a sample image from the training dataframe
sample_row = train_df.iloc[0]
sample_path = sample_row['path']
sample_label = 'Malignant' if sample_row['target'] == 1 else 'Benign'

# Load and convert to array
img = load_img(sample_path, target_size=(224, 224))
x = img_to_array(img)
x = x.reshape((1,) + x.shape)  # Reshape to (1, 224, 224, 3) for the generator

plt.figure(figsize=(15, 6))

# Plot the original image
plt.subplot(2, 4, 1)
plt.imshow(img)
plt.title(f"Original ({sample_label})", fontsize=12, fontweight='bold')
plt.axis('off')

# Generate and plot 7 augmented variations
i = 2
for batch in train_datagen.flow(x, batch_size=1):
    plt.subplot(2, 4, i)
    # Batch elements are already rescaled to [0,1] due to rescale=1./255 in train_datagen
    plt.imshow(batch[0])
    plt.title(f"Augmented {i-1}", fontsize=11)
    plt.axis('off')
    i += 1
    if i > 8:
        break

plt.tight_layout()
plt.suptitle('Visualizing Data Augmentation on a Training Sample', y=1.02, fontsize=14, fontweight='bold')
plt.show()

# %% [markdown]
# ---
# ## 5.  Transfer Learning Architecture
# Each model uses a **frozen pre-trained backbone** + custom binary classification head:
# `GlobalAveragePooling2D  Dense(256, ReLU)  BatchNorm  Dropout(0.4)  Dense(1, Sigmoid)`

# %%
def build_transfer_model(backbone_fn, input_shape=(224, 224, 3)):
    base = backbone_fn(weights='imagenet', include_top=False, input_shape=input_shape)
    for layer in base.layers:
        layer.trainable = False

    x = base.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.4)(x)
    out = Dense(1, activation='sigmoid')(x)

    model = Model(inputs=base.input, outputs=out)
    model.compile(
        optimizer=Adam(learning_rate=1e-4),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    return model

def get_callbacks():
    return [
        ReduceLROnPlateau(monitor='val_loss', patience=3, factor=0.5, min_lr=1e-7, verbose=1),
        EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True, verbose=1)
    ]

print('[OK] Transfer learning builder ready')
# Out:
# [OK] Transfer learning builder ready

# %% [markdown]
# ---
# ## 6.  Training Each Model
# > **Note:** Training is set to **15 epochs** (EarlyStopping may stop sooner).
# > For full training on a GPU, you can increase to 50+ epochs.

# %% [markdown]
# ### 6.1 VGG19

# %%
from tensorflow.keras.applications import VGG19

model_vgg19 = build_transfer_model(VGG19)
print(f'VGG19 trainable params: {sum(p.numpy().size for p in model_vgg19.trainable_weights):,}')

train_gen_224, val_gen_224, test_gen_224 = make_generators((224, 224))

history_vgg19 = model_vgg19.fit(
    train_gen_224, epochs=15, validation_data=val_gen_224,
    callbacks=get_callbacks(), class_weight=class_weights, verbose=1
)
# Out:
# VGG19 trainable params: 132,097
# Found 7235 validated image filenames belonging to 2 classes.
# Found 1277 validated image filenames belonging to 2 classes.
# Found 1503 validated image filenames belonging to 2 classes.
# Epoch 1/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 136s 275ms/step - accuracy: 0.6810 - loss: 0.5941 - val_accuracy: 0.7612 - val_loss: 0.5382 - learning_rate: 1.0000e-04
# Epoch 2/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 101s 222ms/step - accuracy: 0.7204 - loss: 0.5561 - val_accuracy: 0.7298 - val_loss: 0.5680 - learning_rate: 1.0000e-04
# Epoch 3/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 98s 215ms/step - accuracy: 0.7306 - loss: 0.5390 - val_accuracy: 0.6703 - val_loss: 0.7654 - learning_rate: 1.0000e-04
# Epoch 4/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.7341 - loss: 0.5411
# Epoch 4: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 100s 220ms/step - accuracy: 0.7417 - loss: 0.5291 - val_accuracy: 0.7259 - val_loss: 0.5727 - learning_rate: 1.0000e-04
# Epoch 5/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 98s 216ms/step - accuracy: 0.7389 - loss: 0.5263 - val_accuracy: 0.6977 - val_loss: 0.6389 - learning_rate: 5.0000e-05
# Epoch 6/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 93s 205ms/step - accuracy: 0.7433 - loss: 0.5171 - val_accuracy: 0.7142 - val_loss: 0.5733 - learning_rate: 5.0000e-05
# Epoch 7/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 96s 211ms/step - accuracy: 0.7444 - loss: 0.5227 - val_accuracy: 0.7627 - val_loss: 0.5018 - learning_rate: 5.0000e-05
# Epoch 8/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 98s 216ms/step - accuracy: 0.7421 - loss: 0.5186 - val_accuracy: 0.6891 - val_loss: 0.6557 - learning_rate: 5.0000e-05
# Epoch 9/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 100s 220ms/step - accuracy: 0.7500 - loss: 0.5251 - val_accuracy: 0.7940 - val_loss: 0.4594 - learning_rate: 5.0000e-05
# Epoch 10/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 94s 208ms/step - accuracy: 0.7458 - loss: 0.5231 - val_accuracy: 0.6836 - val_loss: 0.6562 - learning_rate: 5.0000e-05
# Epoch 11/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 90s 198ms/step - accuracy: 0.7407 - loss: 0.5159 - val_accuracy: 0.6194 - val_loss: 0.8527 - learning_rate: 5.0000e-05
# Epoch 12/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 88s 194ms/step - accuracy: 0.7454 - loss: 0.5160 - val_accuracy: 0.7956 - val_loss: 0.4306 - learning_rate: 5.0000e-05
# Epoch 13/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 92s 203ms/step - accuracy: 0.7457 - loss: 0.5149 - val_accuracy: 0.6938 - val_loss: 0.6483 - learning_rate: 5.0000e-05
# Epoch 14/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 95s 210ms/step - accuracy: 0.7457 - loss: 0.5111 - val_accuracy: 0.7157 - val_loss: 0.5760 - learning_rate: 5.0000e-05
# Epoch 15/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.7523 - loss: 0.5084
# Epoch 15: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 94s 207ms/step - accuracy: 0.7490 - loss: 0.5120 - val_accuracy: 0.7275 - val_loss: 0.5468 - learning_rate: 5.0000e-05
# Restoring model weights from the end of the best epoch: 12.

# %% [markdown]
# ### 6.2 ResNet50

# %%
from tensorflow.keras.applications import ResNet50

model_resnet50 = build_transfer_model(ResNet50)
train_gen_224, val_gen_224, test_gen_224 = make_generators((224, 224))

history_resnet50 = model_resnet50.fit(
    train_gen_224, epochs=15, validation_data=val_gen_224,
    callbacks=get_callbacks(), class_weight=class_weights, verbose=1
)
# Out:
# Found 7235 validated image filenames belonging to 2 classes.
# Found 1277 validated image filenames belonging to 2 classes.
# Found 1503 validated image filenames belonging to 2 classes.
# Epoch 1/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 118s 224ms/step - accuracy: 0.6629 - loss: 0.5869 - val_accuracy: 0.8050 - val_loss: 0.4502 - learning_rate: 1.0000e-04
# Epoch 2/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 91s 201ms/step - accuracy: 0.6900 - loss: 0.5587 - val_accuracy: 0.5536 - val_loss: 0.8790 - learning_rate: 1.0000e-04
# Epoch 3/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 90s 198ms/step - accuracy: 0.7073 - loss: 0.5463 - val_accuracy: 0.8042 - val_loss: 1.0692 - learning_rate: 1.0000e-04
# Epoch 4/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.7060 - loss: 0.5517
# Epoch 4: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 89s 197ms/step - accuracy: 0.7052 - loss: 0.5460 - val_accuracy: 0.8034 - val_loss: 0.6995 - learning_rate: 1.0000e-04
# Epoch 5/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 91s 201ms/step - accuracy: 0.7173 - loss: 0.5364 - val_accuracy: 0.3704 - val_loss: 1.3289 - learning_rate: 5.0000e-05
# Epoch 6/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 91s 202ms/step - accuracy: 0.7196 - loss: 0.5339 - val_accuracy: 0.8128 - val_loss: 0.4482 - learning_rate: 5.0000e-05
# Epoch 7/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 90s 199ms/step - accuracy: 0.7176 - loss: 0.5318 - val_accuracy: 0.2709 - val_loss: 1.5146 - learning_rate: 5.0000e-05
# Epoch 8/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 91s 201ms/step - accuracy: 0.7202 - loss: 0.5359 - val_accuracy: 0.2005 - val_loss: 2.5852 - learning_rate: 5.0000e-05
# Epoch 9/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 91s 200ms/step - accuracy: 0.7255 - loss: 0.5264 - val_accuracy: 0.8207 - val_loss: 0.4084 - learning_rate: 5.0000e-05
# Epoch 10/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 90s 198ms/step - accuracy: 0.7209 - loss: 0.5286 - val_accuracy: 0.7972 - val_loss: 0.4225 - learning_rate: 5.0000e-05
# Epoch 11/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 91s 200ms/step - accuracy: 0.7255 - loss: 0.5230 - val_accuracy: 0.8034 - val_loss: 0.6756 - learning_rate: 5.0000e-05
# Epoch 12/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.7234 - loss: 0.5097
# Epoch 12: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 91s 200ms/step - accuracy: 0.7258 - loss: 0.5231 - val_accuracy: 0.1950 - val_loss: 4.7750 - learning_rate: 5.0000e-05
# Epoch 13/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 88s 193ms/step - accuracy: 0.7234 - loss: 0.5236 - val_accuracy: 0.6366 - val_loss: 0.6965 - learning_rate: 2.5000e-05
# Epoch 14/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 90s 198ms/step - accuracy: 0.7310 - loss: 0.5211 - val_accuracy: 0.6390 - val_loss: 0.6966 - learning_rate: 2.5000e-05
# Epoch 15/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.7184 - loss: 0.5145
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 86s 189ms/step - accuracy: 0.7190 - loss: 0.5281 - val_accuracy: 0.5983 - val_loss: 0.8074 - learning_rate: 2.5000e-05
# Restoring model weights from the end of the best epoch: 9.

# %% [markdown]
# ### 6.3 ResNet152V2

# %%
from tensorflow.keras.applications import ResNet152V2

model_resnet152v2 = build_transfer_model(ResNet152V2)
train_gen_224, val_gen_224, test_gen_224 = make_generators((224, 224))

history_resnet152v2 = model_resnet152v2.fit(
    train_gen_224, epochs=15, validation_data=val_gen_224,
    callbacks=get_callbacks(), class_weight=class_weights, verbose=1
)
# Out:
# Found 7235 validated image filenames belonging to 2 classes.
# Found 1277 validated image filenames belonging to 2 classes.
# Found 1503 validated image filenames belonging to 2 classes.
# Epoch 1/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 154s 287ms/step - accuracy: 0.6340 - loss: 0.6740 - val_accuracy: 0.6617 - val_loss: 0.7495 - learning_rate: 1.0000e-04
# Epoch 2/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 98s 216ms/step - accuracy: 0.6966 - loss: 0.5735 - val_accuracy: 0.7792 - val_loss: 0.4823 - learning_rate: 1.0000e-04
# Epoch 3/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 92s 204ms/step - accuracy: 0.7197 - loss: 0.5477 - val_accuracy: 0.7463 - val_loss: 0.5535 - learning_rate: 1.0000e-04
# Epoch 4/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 92s 203ms/step - accuracy: 0.7389 - loss: 0.5118 - val_accuracy: 0.7729 - val_loss: 0.4821 - learning_rate: 1.0000e-04
# Epoch 5/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 94s 207ms/step - accuracy: 0.7519 - loss: 0.4935 - val_accuracy: 0.7651 - val_loss: 0.4891 - learning_rate: 1.0000e-04
# Epoch 6/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 95s 210ms/step - accuracy: 0.7581 - loss: 0.4804 - val_accuracy: 0.7698 - val_loss: 0.4806 - learning_rate: 1.0000e-04
# Epoch 7/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 93s 205ms/step - accuracy: 0.7653 - loss: 0.4745 - val_accuracy: 0.7862 - val_loss: 0.4616 - learning_rate: 1.0000e-04
# Epoch 8/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 142s 206ms/step - accuracy: 0.7677 - loss: 0.4692 - val_accuracy: 0.7455 - val_loss: 0.5168 - learning_rate: 1.0000e-04
# Epoch 9/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 90s 199ms/step - accuracy: 0.7607 - loss: 0.4684 - val_accuracy: 0.7549 - val_loss: 0.4962 - learning_rate: 1.0000e-04
# Epoch 10/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 93s 204ms/step - accuracy: 0.7722 - loss: 0.4611 - val_accuracy: 0.7823 - val_loss: 0.4462 - learning_rate: 1.0000e-04
# Epoch 11/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 93s 205ms/step - accuracy: 0.7751 - loss: 0.4430 - val_accuracy: 0.7776 - val_loss: 0.4478 - learning_rate: 1.0000e-04
# Epoch 12/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 93s 204ms/step - accuracy: 0.7719 - loss: 0.4527 - val_accuracy: 0.7784 - val_loss: 0.4584 - learning_rate: 1.0000e-04
# Epoch 13/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.7732 - loss: 0.4504
# Epoch 13: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 91s 200ms/step - accuracy: 0.7802 - loss: 0.4328 - val_accuracy: 0.7784 - val_loss: 0.4581 - learning_rate: 1.0000e-04
# Epoch 14/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 92s 204ms/step - accuracy: 0.7860 - loss: 0.4251 - val_accuracy: 0.7753 - val_loss: 0.4574 - learning_rate: 5.0000e-05
# Epoch 15/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 90s 199ms/step - accuracy: 0.7793 - loss: 0.4269 - val_accuracy: 0.7721 - val_loss: 0.4701 - learning_rate: 5.0000e-05
# Restoring model weights from the end of the best epoch: 10.

# %% [markdown]
# ### 6.4 InceptionV3 (input 299×299)

# %%
from tensorflow.keras.applications import InceptionV3

model_inceptionv3 = build_transfer_model(InceptionV3, input_shape=(299, 299, 3))
train_gen_299, val_gen_299, test_gen_299 = make_generators((299, 299))

history_inceptionv3 = model_inceptionv3.fit(
    train_gen_299, epochs=15, validation_data=val_gen_299,
    callbacks=get_callbacks(), class_weight=class_weights, verbose=1
)
# Out:
# Found 7235 validated image filenames belonging to 2 classes.
# Found 1277 validated image filenames belonging to 2 classes.
# Found 1503 validated image filenames belonging to 2 classes.
# Epoch 1/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 169s 333ms/step - accuracy: 0.6455 - loss: 0.6320 - val_accuracy: 0.7079 - val_loss: 0.6040 - learning_rate: 1.0000e-04
# Epoch 2/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 132s 291ms/step - accuracy: 0.7048 - loss: 0.5465 - val_accuracy: 0.7259 - val_loss: 0.5991 - learning_rate: 1.0000e-04
# Epoch 3/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 132s 292ms/step - accuracy: 0.7252 - loss: 0.5275 - val_accuracy: 0.7886 - val_loss: 0.4283 - learning_rate: 1.0000e-04
# Epoch 4/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 131s 288ms/step - accuracy: 0.7332 - loss: 0.5150 - val_accuracy: 0.7635 - val_loss: 0.4510 - learning_rate: 1.0000e-04
# Epoch 5/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 131s 288ms/step - accuracy: 0.7393 - loss: 0.5034 - val_accuracy: 0.7048 - val_loss: 0.5815 - learning_rate: 1.0000e-04
# Epoch 6/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.7607 - loss: 0.4804
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 129s 286ms/step - accuracy: 0.7580 - loss: 0.4785 - val_accuracy: 0.7181 - val_loss: 0.5678 - learning_rate: 1.0000e-04
# Epoch 7/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 132s 291ms/step - accuracy: 0.7656 - loss: 0.4681 - val_accuracy: 0.7698 - val_loss: 0.4641 - learning_rate: 5.0000e-05
# Epoch 8/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 131s 290ms/step - accuracy: 0.7653 - loss: 0.4671 - val_accuracy: 0.7557 - val_loss: 0.4971 - learning_rate: 5.0000e-05
# Epoch 9/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.7619 - loss: 0.4674
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 133s 293ms/step - accuracy: 0.7617 - loss: 0.4613 - val_accuracy: 0.7549 - val_loss: 0.5031 - learning_rate: 5.0000e-05
# Epoch 10/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 135s 299ms/step - accuracy: 0.7718 - loss: 0.4478 - val_accuracy: 0.7619 - val_loss: 0.4810 - learning_rate: 2.5000e-05
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 3.

# %% [markdown]
# ### 6.5 DenseNet201

# %%
from tensorflow.keras.applications import DenseNet201

model_densenet201 = build_transfer_model(DenseNet201)
train_gen_224, val_gen_224, test_gen_224 = make_generators((224, 224))

history_densenet201 = model_densenet201.fit(
    train_gen_224, epochs=15, validation_data=val_gen_224,
    callbacks=get_callbacks(), class_weight=class_weights, verbose=1
)
# Out:
# Found 7235 validated image filenames belonging to 2 classes.
# Found 1277 validated image filenames belonging to 2 classes.
# Found 1503 validated image filenames belonging to 2 classes.
# Epoch 1/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 238s 412ms/step - accuracy: 0.6571 - loss: 0.6316 - val_accuracy: 0.6664 - val_loss: 0.7398 - learning_rate: 1.0000e-04
# Epoch 2/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 98s 216ms/step - accuracy: 0.7241 - loss: 0.5186 - val_accuracy: 0.7345 - val_loss: 0.5730 - learning_rate: 1.0000e-04
# Epoch 3/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 96s 212ms/step - accuracy: 0.7471 - loss: 0.4928 - val_accuracy: 0.7651 - val_loss: 0.4966 - learning_rate: 1.0000e-04
# Epoch 4/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 97s 214ms/step - accuracy: 0.7616 - loss: 0.4705 - val_accuracy: 0.7666 - val_loss: 0.4780 - learning_rate: 1.0000e-04
# Epoch 5/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 92s 203ms/step - accuracy: 0.7667 - loss: 0.4652 - val_accuracy: 0.7314 - val_loss: 0.5571 - learning_rate: 1.0000e-04
# Epoch 6/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 94s 208ms/step - accuracy: 0.7766 - loss: 0.4409 - val_accuracy: 0.7698 - val_loss: 0.4529 - learning_rate: 1.0000e-04
# Epoch 7/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 91s 200ms/step - accuracy: 0.7849 - loss: 0.4347 - val_accuracy: 0.7510 - val_loss: 0.5161 - learning_rate: 1.0000e-04
# Epoch 8/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 91s 200ms/step - accuracy: 0.7913 - loss: 0.4325 - val_accuracy: 0.8050 - val_loss: 0.4032 - learning_rate: 1.0000e-04
# Epoch 9/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 90s 198ms/step - accuracy: 0.7906 - loss: 0.4242 - val_accuracy: 0.7557 - val_loss: 0.4850 - learning_rate: 1.0000e-04
# Epoch 10/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 93s 205ms/step - accuracy: 0.8037 - loss: 0.4120 - val_accuracy: 0.8081 - val_loss: 0.3944 - learning_rate: 1.0000e-04
# Epoch 11/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 93s 205ms/step - accuracy: 0.7981 - loss: 0.4123 - val_accuracy: 0.7619 - val_loss: 0.4848 - learning_rate: 1.0000e-04
# Epoch 12/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 91s 201ms/step - accuracy: 0.7927 - loss: 0.4190 - val_accuracy: 0.7894 - val_loss: 0.4441 - learning_rate: 1.0000e-04
# Epoch 13/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.8053 - loss: 0.4024
# Epoch 13: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 87s 193ms/step - accuracy: 0.8015 - loss: 0.4056 - val_accuracy: 0.7792 - val_loss: 0.4392 - learning_rate: 1.0000e-04
# Epoch 14/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 95s 210ms/step - accuracy: 0.8105 - loss: 0.3833 - val_accuracy: 0.7760 - val_loss: 0.4810 - learning_rate: 5.0000e-05
# Epoch 15/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 95s 209ms/step - accuracy: 0.8061 - loss: 0.3963 - val_accuracy: 0.7729 - val_loss: 0.4635 - learning_rate: 5.0000e-05
# Restoring model weights from the end of the best epoch: 10.

# %% [markdown]
# ---
# ## 7.  Evaluation and Confusion Matrices

# %%
def evaluate_dl_model(name, model, test_gen, target_size=(224, 224)):
    """Evaluate a DL model and return accuracy and classification report."""
    _, test_g, _ = make_generators(target_size=target_size)
    # Reset generator
    test_g.reset()

    y_prob = model.predict(test_g, verbose=0)
    y_pred = (y_prob.ravel() >= 0.35).astype(int)
    y_true = test_g.classes

    acc = (y_pred == y_true).mean()
    rep = classification_report(y_true, y_pred, target_names=['Benign','Malignant'],
                                 output_dict=True, zero_division=0)
    print(f'\n {name} ')
    print(f'  Accuracy: {acc:.4f}')
    print(classification_report(y_true, y_pred, target_names=['Benign','Malignant'], zero_division=0))
    return acc, rep, y_pred, y_true

dl_results = {}

acc_vgg19, rep_vgg19, pred_vgg19, true_vgg19 = evaluate_dl_model(
    'VGG19', model_vgg19, test_gen_224, (224,224))
acc_rn50, rep_rn50, pred_rn50, true_rn50 = evaluate_dl_model(
    'ResNet50', model_resnet50, test_gen_224, (224,224))
acc_rn152, rep_rn152, pred_rn152, true_rn152 = evaluate_dl_model(
    'ResNet152V2', model_resnet152v2, test_gen_224, (224,224))
acc_inc, rep_inc, pred_inc, true_inc = evaluate_dl_model(
    'InceptionV3', model_inceptionv3, test_gen_299, (299,299))
acc_dn201, rep_dn201, pred_dn201, true_dn201 = evaluate_dl_model(
    'DenseNet201', model_densenet201, test_gen_224, (224,224))
# Out:
# Found 7235 validated image filenames belonging to 2 classes.
# Found 1277 validated image filenames belonging to 2 classes.
# Found 1503 validated image filenames belonging to 2 classes.
#
#  VGG19
#   Accuracy: 0.7400
#               precision    recall  f1-score   support
#
#       Benign       0.94      0.73      0.82      1028
#    Malignant       0.41      0.79      0.54       249
#
#     accuracy                           0.74      1277
#    macro avg       0.67      0.76      0.68      1277
# weighted avg       0.83      0.74      0.76      1277
#
# Found 7235 validated image filenames belonging to 2 classes.
# Found 1277 validated image filenames belonging to 2 classes.
# Found 1503 validated image filenames belonging to 2 classes.
#
#  ResNet50
#   Accuracy: 0.8168
#               precision    recall  f1-score   support
#
#       Benign       0.85      0.93      0.89      1028
#    Malignant       0.55      0.33      0.41       249
#
#     accuracy                           0.82      1277
#    macro avg       0.70      0.63      0.65      1277
# weighted avg       0.79      0.82      0.80      1277
#
# Found 7235 validated image filenames belonging to 2 classes.
# Found 1277 validated image filenames belonging to 2 classes.
# Found 1503 validated image filenames belonging to 2 classes.
#
#  ResNet152V2
#   Accuracy: 0.7314
#               precision    recall  f1-score   support
#
#       Benign       0.95      0.71      0.81      1028
#    Malignant       0.41      0.83      0.55       249
#
#     accuracy                           0.73      1277
#    macro avg       0.68      0.77      0.68      1277
# weighted avg       0.84      0.73      0.76      1277
#
# Found 7235 validated image filenames belonging to 2 classes.
# Found 1277 validated image filenames belonging to 2 classes.
# Found 1503 validated image filenames belonging to 2 classes.
#
#  InceptionV3
#   Accuracy: 0.7471
#               precision    recall  f1-score   support
#
#       Benign       0.92      0.75      0.83      1028
#    Malignant       0.42      0.74      0.53       249
#
#     accuracy                           0.75      1277
#    macro avg       0.67      0.75      0.68      1277
# weighted avg       0.82      0.75      0.77      1277
#
# Found 7235 validated image filenames belonging to 2 classes.
# Found 1277 validated image filenames belonging to 2 classes.
# Found 1503 validated image filenames belonging to 2 classes.
#
#  DenseNet201
#   Accuracy: 0.7604
#               precision    recall  f1-score   support
#
#       Benign       0.91      0.78      0.84      1028
#    Malignant       0.43      0.69      0.53       249
#
#     accuracy                           0.76      1277
#    macro avg       0.67      0.73      0.68      1277
# weighted avg       0.82      0.76      0.78      1277

# %%
# Confusion matrices for all 5 models
model_eval_list = [
    ('VGG19',       pred_vgg19,  true_vgg19),
    ('ResNet50',    pred_rn50,   true_rn50),
    ('ResNet152V2', pred_rn152,  true_rn152),
    ('InceptionV3', pred_inc,    true_inc),
    ('DenseNet201', pred_dn201,  true_dn201),
]

fig, axes = plt.subplots(1, 5, figsize=(24, 4))
for i, (name, preds, trues) in enumerate(model_eval_list):
    cm = confusion_matrix(trues, preds)
    disp = ConfusionMatrixDisplay(cm, display_labels=['Benign','Malignant'])
    disp.plot(ax=axes[i], colorbar=False, cmap='Blues')
    axes[i].set_title(name, fontweight='bold')

plt.suptitle('Confusion Matrices — Deep Learning Models', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## 8.  Training History Plots

# %%
def plot_history(history, name):
    fig, axes = plt.subplots(1, 2, figsize=(14, 4))
    axes[0].plot(history.history['loss'], label='Train Loss', color='#e74c3c')
    axes[0].plot(history.history['val_loss'], label='Val Loss', color='#3498db')
    axes[0].set_title(f'{name} — Loss Curve', fontweight='bold')
    axes[0].set_xlabel('Epoch')
    axes[0].set_ylabel('Loss')
    axes[0].legend()

    axes[1].plot(history.history['accuracy'], label='Train Acc', color='#e74c3c')
    axes[1].plot(history.history['val_accuracy'], label='Val Acc', color='#3498db')
    axes[1].set_title(f'{name} — Accuracy Curve', fontweight='bold')
    axes[1].set_xlabel('Epoch')
    axes[1].set_ylabel('Accuracy')
    axes[1].legend()

    plt.tight_layout()
    plt.show()

for hist, name in [
    (history_vgg19,       'VGG19'),
    (history_resnet50,    'ResNet50'),
    (history_resnet152v2, 'ResNet152V2'),
    (history_inceptionv3, 'InceptionV3'),
    (history_densenet201, 'DenseNet201'),
]:
    plot_history(hist, name)

# %% [markdown]
# ---
# ## 9.  Performance Summary Table

# %%
model_accs = {
    'VGG19'       : (acc_vgg19, rep_vgg19),
    'ResNet50'    : (acc_rn50,  rep_rn50),
    'ResNet152V2' : (acc_rn152, rep_rn152),
    'InceptionV3' : (acc_inc,   rep_inc),
    'DenseNet201' : (acc_dn201, rep_dn201),
}

rows = []
for name, (acc, rep) in model_accs.items():
    rows.append({
        'Model'       : name,
        'Accuracy'    : round(acc, 4),
        'B_Precision' : round(rep['Benign']['precision'], 4),
        'B_Recall'    : round(rep['Benign']['recall'], 4),
        'B_F1'        : round(rep['Benign']['f1-score'], 4),
        'M_Precision' : round(rep['Malignant']['precision'], 4),
        'M_Recall'    : round(rep['Malignant']['recall'], 4),
        'M_F1'        : round(rep['Malignant']['f1-score'], 4),
    })

summary_dl = pd.DataFrame(rows).set_index('Model')
print('Deep Learning Model Performance Summary:')
print(summary_dl.to_string())
summary_dl
# Out:
# Deep Learning Model Performance Summary:
#              Accuracy  B_Precision  B_Recall    B_F1  M_Precision  M_Recall    M_F1
# Model
# VGG19          0.7400       0.9350    0.7276  0.8184       0.4130    0.7912  0.5427
# ResNet50       0.8168       0.8520    0.9348  0.8915       0.5503    0.3293  0.4121
# ResNet152V2    0.7314       0.9454    0.7072  0.8091       0.4075    0.8313  0.5469
# InceptionV3    0.7471       0.9232    0.7481  0.8264       0.4167    0.7430  0.5339
# DenseNet201    0.7604       0.9121    0.7772  0.8393       0.4289    0.6908  0.5292
#              Accuracy  B_Precision  B_Recall    B_F1  M_Precision  M_Recall  \
# Model
# VGG19          0.7400       0.9350    0.7276  0.8184       0.4130    0.7912
# ResNet50       0.8168       0.8520    0.9348  0.8915       0.5503    0.3293
# ResNet152V2    0.7314       0.9454    0.7072  0.8091       0.4075    0.8313
# InceptionV3    0.7471       0.9232    0.7481  0.8264       0.4167    0.7430
# DenseNet201    0.7604       0.9121    0.7772  0.8393       0.4289    0.6908
#
#                M_F1
# Model
# VGG19        0.5427
# ResNet50     0.4121
# ResNet152V2  0.5469
# InceptionV3  0.5339
# DenseNet201  0.5292
